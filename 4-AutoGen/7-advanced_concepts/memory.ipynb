# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient

model_client = OpenAIChatCompletionClient(
    model='gpt-4o-mini',
    temperature=0.0
)

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_core.memory import ListMemory, MemoryContent, MemoryMimeType

# %%
userMemory = ListMemory()

await userMemory.add(MemoryContent(
    content='The weather unit should be degree celsius ( metric)',
    mime_type=MemoryMimeType.TEXT
))

await userMemory.add(MemoryContent(
    content='The User is Vegetarian',
    mime_type=MemoryMimeType.TEXT
))

# %%
async def get_weather(city: str, units: str = "imperial") -> str:
    if units == "imperial":
        return f"The weather in {city} is 73 °F and Sunny."
    elif units == "metric":
        return f"The weather in {city} is 23 °C and Sunny."
    else:
        return f"Sorry, I don't know the weather in {city}."

# %%
assistant_agent = AssistantAgent(
    'my_assistant',
    model_client=model_client,
    tools=[get_weather],
    memory=[userMemory]
)

# %%
stream = assistant_agent.run_stream(task='What is the weather in Delhi ?')
await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# What is the weather in Delhi ?
# ---------- MemoryQueryEvent (my_assistant) ----------
# [MemoryContent(content='The weather unit should be degree celsius ( metric)', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None), MemoryContent(content='The User is Vegetarian', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None)]
# ---------- ToolCallRequestEvent (my_assistant) ----------
# [FunctionCall(id='call_dqQ315N31VRXvnfRWDqkwsSQ', arguments='{"city":"Delhi","units":"metric"}', name='get_weather')]
# ---------- ToolCallExecutionEvent (my_assistant) ----------
# [FunctionExecutionResult(content='The weather in Delhi is 23 °C and Sunny.', name='get_weather', call_id='call_dqQ315N31VRXvnfRWDqkwsSQ', is_error=False)]
# ---------- ToolCallSummaryMessage (my_assistant) ----------
# The weather in Delhi is 23 °C and Sunny.
# TaskResult(messages=[TextMessage(id='5501933b-6048-4bbb-82b5-4bfcaa6a630b', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 15, 348234, tzinfo=datetime.timezone.utc), content='What is the weather in Delhi ?', type='TextMessage'), MemoryQueryEvent(id='0834c1c2-23d6-42ac-88bd-f76e1f3e5a12', source='my_assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 15, 364319, tzinfo=datetime.timezone.utc), content=[MemoryContent(content='The weather unit should be degree celsius ( metric)', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None), MemoryContent(content='The User is Vegetarian', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None)], type='MemoryQueryEvent'), ToolCallRequestEvent(id='43bda25b-d2eb-4bb7-8ebb-08c31175f81c', source='my_assistant', models_usage=RequestUsage(prompt_tokens=124, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 16, 775400, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_dqQ315N31VRXvnfRWDqkwsSQ', arguments='{"city":"Delhi","units":"metric"}', name='get_weather')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='2eaa097a-6798-4c96-bf11-a285b75fbde9', source='my_assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 16, 778711, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='The weather in Delhi is 23 °C and Sunny.', name='get_weather', call_id='call_dqQ315N31VRXvnfRWDqkwsSQ', is_error=False)], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(id='7f4ab8bc-7ee4-4f81-8da7-b38ed3d68c9d', source='my_assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 16, 781705, tzinfo=datetime.timezone.utc), content='The weather in Delhi is 23 °C and Sunny.', type='ToolCallSummaryMessage', tool_calls=[FunctionCall(id='call_dqQ315N31VRXvnfRWDqkwsSQ', arguments='{"city":"Delhi","units":"metric"}', name='get_weather')], results=[FunctionExecutionResult(content='The weather in Delhi is 23 °C and Sunny.', name='get_weather', call_id='call_dqQ315N31VRXvnfRWDqkwsSQ', is_error=False)])], stop_reason=None)

# %%
stream = assistant_agent.run_stream(task='Can you give me a good high protien diet ?')
await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# Can you give me a good high protien diet ?
# ---------- MemoryQueryEvent (my_assistant) ----------
# [MemoryContent(content='The weather unit should be degree celsius ( metric)', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None), MemoryContent(content='The User is Vegetarian', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None)]
# ---------- TextMessage (my_assistant) ----------
# Here’s a high-protein vegetarian diet plan you can consider:
#
# ### Breakfast
# - **Greek Yogurt Parfait**: 1 cup of Greek yogurt topped with mixed berries and a sprinkle of chia seeds.
# - **Smoothie**: Blend spinach, banana, protein powder, and almond milk.
#
# ### Snack
# - **Cottage Cheese**: 1 cup of low-fat cottage cheese with sliced peaches or pineapple.
# - **Nuts**: A handful of almonds or walnuts.
#
# ### Lunch
# - **Quinoa Salad**: Quinoa mixed with black beans, corn, diced bell peppers, and avocado, dressed with lime juice.
# - **Lentil Soup**: A bowl of lentil soup with whole-grain bread.
#
# ### Snack
# - **Hummus and Veggies**: Hummus served with carrot sticks, cucumber slices, and bell pepper strips.
# - **Protein Bar**: A low-sugar protein bar.
#
# ### Dinner
# - **Chickpea Stir-Fry**: Stir-fried chickpeas with broccoli, bell peppers, and tofu, served over brown rice.
# - **Stuffed Peppers**: Bell peppers stuffed with a mixture of brown rice, black beans, corn, and spices.
#
# ### Dessert (Optional)
# - **Protein Pancakes**: Made with oats, banana, and protein powder, topped with a drizzle of maple syrup.
#
# ### Hydration
# - Drink plenty of water throughout the day, and consider herbal teas or infused water for variety.
#
# This plan provides a good balance of protein from various vegetarian sources. Adjust portion sizes based on your specific dietary needs and activity level.
# TaskResult(messages=[TextMessage(id='fa78eb6c-4f73-4098-a777-0d430aa8ae9c', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 54, 871557, tzinfo=datetime.timezone.utc), content='Can you give me a good high protien diet ?', type='TextMessage'), MemoryQueryEvent(id='e6cdc663-c0bb-48f7-806d-e5e707528cae', source='my_assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 2, 54, 873631, tzinfo=datetime.timezone.utc), content=[MemoryContent(content='The weather unit should be degree celsius ( metric)', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None), MemoryContent(content='The User is Vegetarian', mime_type=<MemoryMimeType.TEXT: 'text/plain'>, metadata=None)], type='MemoryQueryEvent'), TextMessage(id='1da19638-62b8-481e-a0e3-55eec405dad7', source='my_assistant', models_usage=RequestUsage(prompt_tokens=211, completion_tokens=328), metadata={}, created_at=datetime.datetime(2025, 8, 7, 15, 3, 1, 570032, tzinfo=datetime.timezone.utc), content='Here’s a high-protein vegetarian diet plan you can consider:\n\n### Breakfast\n- **Greek Yogurt Parfait**: 1 cup of Greek yogurt topped with mixed berries and a sprinkle of chia seeds.\n- **Smoothie**: Blend spinach, banana, protein powder, and almond milk.\n\n### Snack\n- **Cottage Cheese**: 1 cup of low-fat cottage cheese with sliced peaches or pineapple.\n- **Nuts**: A handful of almonds or walnuts.\n\n### Lunch\n- **Quinoa Salad**: Quinoa mixed with black beans, corn, diced bell peppers, and avocado, dressed with lime juice.\n- **Lentil Soup**: A bowl of lentil soup with whole-grain bread.\n\n### Snack\n- **Hummus and Veggies**: Hummus served with carrot sticks, cucumber slices, and bell pepper strips.\n- **Protein Bar**: A low-sugar protein bar.\n\n### Dinner\n- **Chickpea Stir-Fry**: Stir-fried chickpeas with broccoli, bell peppers, and tofu, served over brown rice.\n- **Stuffed Peppers**: Bell peppers stuffed with a mixture of brown rice, black beans, corn, and spices.\n\n### Dessert (Optional)\n- **Protein Pancakes**: Made with oats, banana, and protein powder, topped with a drizzle of maple syrup.\n\n### Hydration\n- Drink plenty of water throughout the day, and consider herbal teas or infused water for variety.\n\nThis plan provides a good balance of protein from various vegetarian sources. Adjust portion sizes based on your specific dietary needs and activity level.', type='TextMessage')], stop_reason=None)
